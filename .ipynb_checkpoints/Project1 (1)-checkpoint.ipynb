# %% [markdown]
# # Install libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install pyodbc

# %% [markdown]
# # Connecting to Azure SQL server

# %%
import pandas as pd
import pyodbc as odbc
import matplotlib.pyplot as plt

#connecting to server using odbc
sql_conn = odbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=Johndroescher.com;DATABASE=Fall_2022;UID=satasnimahmed375;PWD=CCny23349375;')

#create dataframs using SQL Queries
query_1 = "SELECT * FROM violation_data"
df1 = pd.read_sql(query_1, sql_conn) #df1 has violation data

query_2 = "SELECT * FROM restaurant_data"
df2 = pd.read_sql(query_2, sql_conn) #df2 has restaurant data

# %%
# check if data is available 
df1.head(2)
# Out:
#   column1     camis violation_code  \
# 0   11332  50010393            04N
# 1   11333  50099700            02B
#
#                                violation_description  \
# 0  Filth flies or food/refuse/sewage-associated (...
# 1         Hot food item not held at or above 140º F.
#
#                                             action  score  \
# 0  Violations were cited in the following area(s).   12.0
# 1  Violations were cited in the following area(s).   13.0
#
#                             inspection_type grade grade_date inspection_date  \
# 0          Cycle Inspection / Re-inspection     A 2019-10-15      2019-10-15
# 1  Pre-permit (Operational) / Re-inspection     A 2020-01-30      2020-01-30
#
#   critical_flag         record_date
# 0      Critical 2022-08-27 06:00:12
# 1      Critical 2022-08-27 06:00:12

# %%
df2.tail(2)
# Out:
#       column1     camis       dba      boro building         street zipcode  \
# 27958  176356  50127067  ZHU CHEN     Bronx     2647  JEROME AVENUE   10468
# 27959  186130  50127068      None  Brooklyn      706      56 STREET   11220
#
#             phone   latitude  longitude community_board council_district  \
# 27958  3472163843  40.866947 -73.897812             207               14
# 27959  7183087684  40.638916 -74.009163             307               38
#
#        census_tract        bin         bbl   nta cuisine_description
# 27958       26500.0  2014397.0  2032020038  BX30                None
# 27959       10400.0  3015509.0  3008420010  BK34                None

# %%
hello = pd.merge(df1, df2, on='camis')

# %%
hello
# Out:
#        column1_x     camis violation_code  \
# 0          11332  50010393            04N
# 1          18909  50010393            08A
# 2          56546  50010393            04L
# 3         136813  50010393            04N
# 4         186775  50010393            08A
# ...          ...       ...            ...
# 248015    247768  50122875           None
# 248016    247826  50120707           None
# 248017    247833  50116939           None
# 248018    247894  50117920            10J
# 248019    247978  50067499            10F
#
#                                     violation_description  \
# 0       Filth flies or food/refuse/sewage-associated (...
# 1       Facility not vermin proof. Harborage or condit...
# 2       Evidence of mice or live mice present in facil...
# 3       Filth flies or food/refuse/sewage-associated (...
# 4       Facility not vermin proof. Harborage or condit...
# ...                                                   ...
# ...

# %% [markdown]
# # Cleaning data

# %% [markdown]
# # Testing data

# %%
query = "SELECT restaurant_data.camis as rest_camis,violation_data.camis as viol_camis, restaurant_data.boro, restaurant_data.zipcode, violation_data.grade,violation_data.critical_flag FROM restaurant_data INNER JOIN violation_data ON restaurant_data.camis = violation_data.camis;"
joined_df = pd.read_sql(query, sql_conn)

# %%
joined_df
# Out:
#         rest_camis  viol_camis       boro zipcode grade critical_flag
# 0         50010393    50010393  Manhattan   10034     A      Critical
# 1         50099700    50099700  Manhattan   10038     A      Critical
# 2         50111874    50111874  Manhattan   10001  None      Critical
# 3         41640776    41640776   Brooklyn   11237     A  Not Critical
# 4         50088892    50088892     Queens   11421  None      Critical
# ...            ...         ...        ...     ...   ...           ...
# 248015    50015281    50015281  Manhattan   10025     A  Not Critical
# 248016    50066680    50066680     Queens   11372     A      Critical
# 248017    50045154    50045154  Manhattan   10036  None      Critical
# 248018    50070200    50070200  Manhattan   10016     B      Critical
# 248019    50044140    50044140  Manhattan   10023  None      Critical
#
# [248020 rows x 6 columns]

# %%
joined_df[['boro']].value_counts()
# Out:
# boro
# Manhattan        93120
# Brooklyn         63282
# Queens           59307
# Bronx            24053
# Staten Island     8181
# 0                   77
# dtype: int64

# %%
new_df = joined_df.dropna()

# %%
new_df
# Out:
#         rest_camis  viol_camis       boro zipcode grade critical_flag
# 0         50010393    50010393  Manhattan   10034     A      Critical
# 1         50099700    50099700  Manhattan   10038     A      Critical
# 3         41640776    41640776   Brooklyn   11237     A  Not Critical
# 5         50098786    50098786  Manhattan   10065     N  Not Critical
# 6         41243875    41243875     Queens   11419     A  Not Critical
# ...            ...         ...        ...     ...   ...           ...
# 248010    50093410    50093410      Bronx   10469     A      Critical
# 248014    41021233    41021233     Queens   11415     A      Critical
# 248015    50015281    50015281  Manhattan   10025     A  Not Critical
# 248016    50066680    50066680     Queens   11372     A      Critical
# 248018    50070200    50070200  Manhattan   10016     B      Critical
#
# [119356 rows x 6 columns]

# %%
new_df[['boro']].value_counts()
# Out:
# boro
# Manhattan        44497
# Brooklyn         30329
# Queens           28567
# Bronx            11543
# Staten Island     4392
# 0                   28
# dtype: int64

# %%
#new_df[['boro']=='0']
dff = new_df.loc[new_df['boro']!='0']

# %%
dff[['boro']].value_counts()
# Out:
# boro
# Manhattan        44497
# Brooklyn         30329
# Queens           28567
# Bronx            11543
# Staten Island     4392
# dtype: int64

# %%
dff[['grade']].value_counts()
# Out:
# grade
# A        90709
# B        11936
# N         7130
# C         5258
# Z         3184
# P         1111
# dtype: int64

# %%
bins = 5
  
# plotting a histogram
plt.hist(dff['boro'], bins, color = 'green',histtype = 'bar', rwidth = 0.8)
# Out:
# (array([44497., 30329., 28567.,  4392., 11543.]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(dff['grade'], 6, color = 'blue',histtype = 'bar', rwidth = 0.8)
# Out:
# (array([90709.,  7130., 11936.,  5258.,  3184.,  1111.]),
#  array([0.        , 0.83333333, 1.66666667, 2.5       , 3.33333333,
#         4.16666667, 5.        ]),
#  <BarContainer object of 6 artists>)

# %%
plt.pie(dff['zipcode'], labels = dff['boro'])
plt.show()
